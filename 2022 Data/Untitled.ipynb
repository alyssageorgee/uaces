# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

file_path = 'world-administrative-boundaries.geojson'
map_df = gpd.read_file(file_path)
map_df.head()
# Out:
#                                  french_short  \
# 0  South Georgia & the South Sandwich Islands
# 1                                    Mongolie
# 2                                     Espagne
# 3                                      Chypre
# 4                                       Macao
#
#                              status  \
# 0                      UK Territory
# 1                      Member State
# 2                      Member State
# 3                      Member State
# 4  CN Special Administrative Region
#
#                                          name color_code   continent  iso3  \
# 0  South Georgia & the South Sandwich Islands        GBR  Antarctica  None
# 1                                    Mongolia        MNG        Asia   MNG
# 2                                       Spain        ESP      Europe   ESP
# 3                                      Cyprus        CYP        Asia   CYP
# 4                                       Macao        CHN        Asia   MAC
#
# ...

# %%
map_df.plot()
# Out:
# <AxesSubplot:>

# %%
df =pd.read_excel('Attendees/2018 Bath.xlsx')
df.head()
# Out:
#                   organisation countrycode    country participant_group  \
# 0       University of Canberra          AU  Australia            Member
# 1     The University of Sydney          AU  Australia        Non-Member
# 2          Flinders University          AU  Australia        Non-Member
# 3  The University of Melbourne          AU  Australia    Student Member
# 4      University of Melbourne          AU  Australia            Member
#
#    Unnamed: 4         name  number of attendants
# 0         NaN        Abyei                   NaN
# 1         NaN  Afghanistan                   NaN
# 2         NaN   Aksai Chin                   NaN
# 3         NaN      Albania                   NaN
# 4         NaN      Algeria                   NaN

# %%
df_merged = pd.merge(map_df,df)
df_merged.head()
# Out:
#                                  french_short  \
# 0  South Georgia & the South Sandwich Islands
# 1                                    Mongolie
# 2                                     Espagne
# 3                                      Chypre
# 4                                       Macao
#
#                              status  \
# 0                      UK Territory
# 1                      Member State
# 2                      Member State
# 3                      Member State
# 4  CN Special Administrative Region
#
#                                          name color_code   continent  iso3  \
# 0  South Georgia & the South Sandwich Islands        GBR  Antarctica  None
# 1                                    Mongolia        MNG        Asia   MNG
# 2                                       Spain        ESP      Europe   ESP
# 3                                      Cyprus        CYP        Asia   CYP
# 4                                       Macao        CHN        Asia   MAC
#
# ...

# %%
df_merged['number of attendants'] = df_merged['number of attendants'].fillna(0)

# %%
import matplotlib as mpl
fig, ax = plt.subplots(1, figsize=(15,6))
vmax = df_merged[df_merged["number of attendants"] < 200]["number of attendants"].max()
vmin = df_merged["number of attendants"].min()
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
df_merged.plot(column='number of attendants', cmap='Blues', linewidth=1, ax=ax, edgecolor='0.9', legend = True, norm=norm)
ax.axis('off')
ax.set_title('Number Of Attendants in Bath, 2018', fontdict={'fontsize': '20', 'fontweight' : '3'})
# Out:
# Text(0.5, 1.0, 'Number Of Attendants in Bath, 2018')

# %%
df_merged[["number of attendants"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3x/w_p1xszx1rg9q2kxl3fzz4n40000gn/T/ipykernel_96606/2675772816.py in <module>
# ----> 1 df_merged[["number of attendants"]].values()
#
# TypeError: 'numpy.ndarray' object is not callable
